# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
data = pd.read_csv("/content/car_data.csv")
df = pd.DataFrame(data)
df
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyota        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
# Visualize Volume vs CO2
plt.scatter(df['Volume'], df['CO2'], color='red', marker='.')
plt.xlabel("Volume")
plt.ylabel("CO2")
plt.title("Volume vs CO2 Emission")
plt.grid()
plt.show()

# Visualize Weight vs CO2
plt.scatter(df['Weight'], df['CO2'], color='blue', marker='.')
plt.xlabel("Weight")
plt.ylabel("CO2")
plt.title("Weight vs CO2 Emission")
plt.grid()
plt.show()

# %%
x=df[['Weight','Volume']]

# %%
y=df['CO2']

# %%
print(x,y)
# Out:
#     Weight  Volume
# 0      790    1000
# 1     1160    1200
# 2      929    1000
# 3      865     900
# 4     1140    1500
# 5      929    1000
# 6     1109    1400
# 7     1365    1500
# 8     1112    1500
# 9     1150    1600
# 10     980    1100
# 11     990    1300
# 12    1112    1000
# 13    1252    1600
# 14    1326    1600
# 15    1330    1600
# 16    1365    1600
# 17    1280    2200
# 18    1119    1600
# 19    1328    2000
# 20    1584    1600
# 21    1428    2000
# 22    1365    2100
# 23    1415    1600
# 24    1415    2000
# 25    1465    1500
# 26    1490    2000
# 27    1725    2000
# 28    1523    1600
# 29    1705    2000
# 30    1605    2100
# 31    1746    2000
# 32    1235    1600
# 33    1390    1600
# 34    1405    1600
# 35    1395    2500 0      99
# 1      95
# 2      95
# 3      90
# 4     105
# 5     105
# 6      90
# 7      92
# 8      98
# 9      99
# 10     99
# 11    101
# 12     99
# 13     94
# 14     97
# 15     97
# 16     99
# 17    104
# ...

# %%
plt.scatter(data['Volume'],data['CO2'],color='red',marker=".")
plt.title("Volume vs CO2")
plt.grid()
plt.show()

# %%
plt.plot(x_train,y_train,'o')
plt.plot(x_test,y_test,'o')
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

print("Test Accuracy (R²):", model.score(x_test, y_test))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
# Out:
# Test Accuracy (R²): 0.32941109624012777
# Mean Squared Error: 58.07928583657768

# %%
# Compare actual vs predicted
plt.scatter(y_test, y_pred, color='green')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='black', lw=2)
plt.xlabel("Actual CO2")
plt.ylabel("Predicted CO2")
plt.title("Actual vs Predicted CO2 Emission")
plt.grid()
plt.show()
